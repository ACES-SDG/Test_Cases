# %%
import pandas as pd
import mysql.connector

# %%
db = mysql.connector.connect(host ='47.91.124.29',
									user = 'msweb_prd_mazhar',
									password = 'P)O(n@7830',
									db ="user_details")
print("Connected to database successfully")
# Out:
# Connected to database successfully

# %%
x = 'user_details'
y='user_details'
df = pd.read_sql_query(f" SELECT * FROM {x}.{y} ", db)
# Out:
# C:\Users\Mazhar\AppData\Local\Temp\ipykernel_12812\2535612597.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql_query(" SELECT * FROM user_details.user_details ", db)

# %%
df.columns
# Out:
# Index(['id', 'user_name', 'aces_id', 'fname', 'lname', 'email', 'phone', 'dob',
#        'passport', 'crt_ts', 'chg_ts', 'crt_by', 'chg_by', 'deleted',
#        'citizenship', 'iqama_number', 'iqama_expiry', 'whatsapp', 'department',
#        'skill', 'shift', 'reporting_to', 'company', 'site_id', 'gender',
#        'region', 'code_id', 'field_mobile', 'section', 'reporting_manager',
#        'punch_in', 'punch_out', 'job_title'],
#       dtype='object')

# %%
df.head()
# Out:
#    id user_name   aces_id               fname lname  \
# 0  52    psurya    psurya    Surya VaraPrasad
# 1  53   rajeshp   rajeshp      Rajesh Puvvala
# 2  54  jeelanib  jeelanib       Jeelani Basha
# 3  55    kiranp    kiranp       kiran Puvvala
# 4  56      ramk      ramk  Rami Reddy Kodanda
#
#                        email         phone         dob passport  \
# 0     suryawork574@gmail.com  919562044588  2000-01-01
# 1       rajesh.p@aces-co.com  919886234018  2000-01-01
# 2  jeelani.basha@aces-co.com  919448387107  2000-01-01
# 3     geturkiran.p@gmail.com    8095687577  2000-01-01
# 4        vkrreddy2@gmail.com    9591841706  2000-01-01
#
#                crt_ts  ... site_id gender region  code_id  field_mobile  \
# 0 2022-12-07 11:07:32  ...              M     CR     RM#2    9562044588
# 1 2022-12-07 11:19:26  ...              M     CR     RM#3    9886234018
# 2 2022-12-07 11:30:33  ...              M     CR     PM#5  919448387107
# 3 2022-12-07 11:33:17  ...              M  INDIA     None          None
# 4 2022-12-07 12:07:04  ...              M     CR     RM#5    9591841706
#
#   section reporting_manager punch_in punch_out       job_title
# 0      EM           rajeshp     None      None   Region Manger
# 1      EM          jeelanib     None      None   Region Manger
# 2      EM        mazher_mnm     None      None  Project Manger
# 3    None          jeelanib     None      None   Region Manger
# 4      EM          jeelanib     None      None   Region Manger
#
# [5 rows x 33 columns]

# %%
df.shape
# Out:
# (226, 33)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 226 entries, 0 to 225
# Data columns (total 33 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 226 non-null    int64
#  1   user_name          226 non-null    object
#  2   aces_id            226 non-null    object
#  3   fname              226 non-null    object
#  4   lname              9 non-null      object
#  5   email              226 non-null    object
#  6   phone              226 non-null    object
#  7   dob                226 non-null    object
#  8   passport           17 non-null     object
#  9   crt_ts             226 non-null    datetime64[ns]
#  10  chg_ts             226 non-null    datetime64[ns]
#  11  crt_by             9 non-null      object
#  12  chg_by             9 non-null      object
#  13  deleted            226 non-null    int64
#  14  citizenship        17 non-null     object
#  15  iqama_number       226 non-null    object
#  16  iqama_expiry       19 non-null     object
#  17  whatsapp           226 non-null    object
#  18  department         226 non-null    object
#  19  skill              17 non-null     object
#  20  shift              17 non-null     object
#  21  reporting_to       17 non-null     object
#  22  company            17 non-null     object
#  23  site_id            17 non-null     object
#  24  gender             226 non-null    object
#  25  region             226 non-null    object
#  26  code_id            219 non-null    object
#  27  field_mobile       219 non-null    object
#  28  section            219 non-null    object
#  29  reporting_manager  222 non-null    object
#  30  punch_in           209 non-null    object
#  31  punch_out          209 non-null    object
#  32  job_title          226 non-null    object
# dtypes: datetime64[ns](2), int64(2), object(29)
# memory usage: 58.4+ KB

# %%
df[df['deleted']==0]
# Out:
#       id        user_name          aces_id                      fname lname  \
# 0     52           psurya           psurya           Surya VaraPrasad
# 1     53          rajeshp          rajeshp             Rajesh Puvvala
# 2     54         jeelanib         jeelanib              Jeelani Basha
# 3     55           kiranp           kiranp              kiran Puvvala
# 4     56             ramk             ramk         Rami Reddy Kodanda
# ..   ...              ...              ...                        ...   ...
# 220  314  maamoun.mohamed  maamoun.mohamed            Maamoun Mohamed  None
# 222  316             0099             0099                  Alaa fin2  None
# 223  317        f.alroubi        f.alroubi  Fares Riyadh Dawod Alroby  None
# 224  318       test_admin       test_admin                 Test Admin  None
# 225  319          test_pm          test_pm                  Test User  None
#
#                            email         phone         dob passport  \
# 0         suryawork574@gmail.com  919562044588  2000-01-01
# 1           rajesh.p@aces-co.com  919886234018  2000-01-01
# 2      jeelani.basha@aces-co.com  919448387107  2000-01-01
# 3         geturkiran.p@gmail.com    8095687577  2000-01-01
# 4            vkrreddy2@gmail.com    9591841706  2000-01-01
# ..                           ...           ...         ...      ...
# 220  Mamoon.Mohammed@aces-co.com  966548802036  2000-01-01     None
# 222             alaa@aces-co.com   00000000000  2000-01-01     None
# 223    faris.alroubi@aces-co.com  966500502117  2000-01-01     None
# 224     mohdmazhar9299@gmail.com  917386949251  2000-01-01     None
# 225         dataofaces@gmail.com  917386949251  2000-01-01     None
#
#                  crt_ts  ... site_id gender  region   code_id  field_mobile  \
# 0   2022-12-07 11:07:32  ...              M      CR      RM#2    9562044588
# 1   2022-12-07 11:19:26  ...              M      CR      RM#3    9886234018
# 2   2022-12-07 11:30:33  ...              M      CR      PM#5  919448387107
# 3   2022-12-07 11:33:17  ...              M   INDIA      None          None
# 4   2022-12-07 12:07:04  ...              M      CR      RM#5    9591841706
# ..                  ...  ...     ...    ...     ...       ...           ...
# 220 2023-07-03 16:40:19  ...    None      M      CR     RM#29  966548802036
# 222 2023-07-17 10:24:07  ...    None      M  Riyadh     F2#36   00000000000
# 223 2023-07-19 15:23:25  ...    None      M      WR  TECH#130  966500502117
# 224 2023-07-28 12:00:08  ...    None      M      CR      OD#7  917386949251
# 225 2023-07-28 12:04:43  ...    None      M      CR      PM#8  917386949251
#
#                  section reporting_manager punch_in punch_out  \
# 0                     EM           rajeshp     None      None
# 1                     EM          jeelanib     None      None
# 2                     EM        mazher_mnm     None      None
# 3                   None          jeelanib     None      None
# 4                     EM          jeelanib     None      None
# ..                   ...               ...      ...       ...
# 220                  DCO            hussam
# 222  Personal Department
# 223            Mobily DC       m.abdelhady
# 224            Mobily DC            hussam
# 225            Mobily DC        test_admin
#
#               job_title
# 0         Region Manger
# 1         Region Manger
# 2        Project Manger
# 3         Region Manger
# 4         Region Manger
# ..                  ...
# 220       Region Manger
# 222         Finance Two
# 223          Technician
# 224  Operation Director
# 225      Project Manger
#
# [211 rows x 33 columns]

# %%
df[df['deleted']==1]
# Out:
#       id         user_name           aces_id                          fname  \
# 78   168   mohammed.sameer   mohammed.sameer                Mohammed Sameer
# 88   182       m.shereshre       m.shereshre  Mohamed Hamed Ahmed Shereshre
# 95   189   alaminmalaminm1   alaminmalaminm1      ALAMIN MOHAMMAD ZARU MIAH
# 98   192     m.alghamdi026     m.alghamdi026        Mohamed Masfer Alghamdy
# 103  197    sobhanabdus673    sobhanabdus673                 ABDUS   SOBHAN
# 104  198  salouddinkhan127  salouddinkhan127      SALA UDDIN BELLAL HOSSAIN
# 116  210           asayyed           asayyed                   Sayyed Aftab
# 118  212         mohd.umar         mohd.umar                      Mohd Umar
# 174  268    rakan.alshmmri    rakan.alshmmri                 RAKAN Alshmmri
# 202  296          acesfin1          acesfin1                  aces finance1
# 203  297          acesfin2          acesfin2                  aces finance2
# 204  298         test_safi         test_safi                      test_safi
# 205  299        test_yaser        test_yaser                     test_yaser
# 210  304             sohel             sohel                  Sohil Mejbaha
# 221  315              9999              9999                         delete
#
#     lname                        email         phone         dob passport  \
# 78   None  mohammed.sameer@aces-co.com   15513886106  2000-01-01     None
# 88   None    m.shereshre@mobily.com.sa  966547144017  2000-01-01     None
# 95   None    alaminmalaminm1@gmail.com  966502783397  2000-01-01     None
# 98   None  m.alghamdi026@mobily.com.sa  966502412518  2000-01-01     None
# 103  None     sobhanabdus673@gmail.com  966573442199  2000-01-01     None
# 104  None   salouddinkhan127@gmail.com  966557562067  2000-01-01     None
# 116  None        asayyed@mobily.com.sa  966541663029  2000-01-01     None
# 118  None       mohd.umar255@gmail.com  966560235214  2000-01-01     None
# 174  None   rakan.alshmmri@aces-co.com  966540535261  2000-01-01     None
# 202  None         rajesh.p@aces-co.com  919886234018  2000-01-01     None
# 203  None    jeelani.basha@aces-co.com  919448387107  2000-01-01     None
# 204  None      creamstone132@gmail.com  918367462446  2000-01-01     None
# 205  None      yaseer.sattar@gmail.com  966545036904  2000-01-01     None
# 210  None               abcd@gmail.com  966561335144  2000-01-01     None
# 221  None                  delte@d.com   00000000000  2000-01-01     None
#
#                  crt_ts  ... site_id gender region   code_id  field_mobile  \
# 78  2023-02-05 13:45:25  ...    None      M     NR      SE#1   15513886106
# 88  2023-04-06 02:34:30  ...    None      M     WR     SOM#2  966547144017
# 95  2023-04-06 03:08:35  ...    None      M     WR   TECH#45  966502783397
# 98  2023-04-06 04:22:48  ...    None      M     WR      SE#8  966502412518
# 103 2023-04-06 04:32:03  ...    None      M     WR   TECH#51  966573442199
# 104 2023-04-06 04:33:07  ...    None      M     WR   TECH#52  966557562067
# 116 2023-04-06 08:18:13  ...    None      M     ER     SE#14  966541663029
# 118 2023-04-06 08:22:35  ...    None      M     ER   TECH#57  966560235214
# 174 2023-04-06 09:39:05  ...    None      M     ER     SOM#7  966540535261
# 202 2023-04-08 18:11:47  ...    None      M     NR  TECH#128  919886234018
# 203 2023-04-08 18:15:31  ...    None      M     NR  TECH#129  919448387107
# 204 2023-04-09 11:43:55  ...    None      M     CR  TECH#125  918367462446
# 205 2023-04-09 11:47:24  ...    None      M     CR    SUP#21  966545036904
# 210 2023-04-17 09:09:23  ...    None      M     WR     SE#29  966561335144
# 221 2023-07-06 13:23:00  ...    None      M     WR    SUP#27   00000000000
#
#     section reporting_manager  punch_in punch_out                job_title
# 78       EM         arifsohel                                Site Engineer
# 88      DCO       m.abdelhady                      Site Operations Manager
# 95      DCO         a.elbakri                                   Technician
# 98      DCO         w.ibrahim                                Site Engineer
# 103     DCO         w.ibrahim                                   Technician
# 104     DCO         w.ibrahim                                   Technician
# 116     DCO    a.ahmedalsanan                                Site Engineer
# 118     DCO    a.ahmedalsanan                                   Technician
# 174     DCO                 -                      Site Operations Manager
# 202     DCO       mazharuddin  Off-Site  Off-Site               Technician
# 203      EM                    Off-Site  Off-Site               Technician
# 204      EM         arifsohel                                   Technician
# 205      EM         arifsohel                                   Supervisor
# 210     DCO       m.abdelhady                                Site Engineer
# 221      EM                91                                   Supervisor
#
# [15 rows x 33 columns]

# %%
df['department'].unique()
# Out:
# array(['Mobily MNS', 'EM', 'TECH', 'Management', 'Mgmt', '', 'Finance',
#        'Security', 'Personal Department', 'MS'], dtype=object)

# %%
df['department'].unique().__len__()
# Out:
# 10

# %%
df['department'].value_counts()
# Out:
# Mobily MNS             207
# EM                       5
# TECH                     4
# MS                       3
# Mgmt                     2
# Management               1
#                          1
# Finance                  1
# Security                 1
# Personal Department      1
# Name: department, dtype: int64

# %%
df['department'].isna().sum()
# Out:
# 0

# %%
df['region']
